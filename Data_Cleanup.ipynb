# %%
# Import Dependencies
import pandas as pd
from pathlib import Path

# %%
# File Setup

# File was taken from https://s3.amazonaws.com/tripdata/index.html

# Read Housing Data and store into Panda DataFrame
df = pd.read_csv("Raw_Data/JC-202309-citibike-tripdata.csv")

# Show DataFrame
df.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  4052081EAF41D252  classic_bike  2023-09-01 17:25:27  2023-09-01 17:31:13
# 1  330043C418DD78E3  classic_bike  2023-09-01 12:57:39  2023-09-01 13:08:50
# 2  4D0F3462818482CF  classic_bike  2023-09-28 08:52:24  2023-09-28 09:15:37
# 3  BF4A3EBF9352E283  classic_bike  2023-09-02 15:25:33  2023-09-02 15:57:11
# 4  957FA73CA6E0C552  classic_bike  2023-09-14 16:46:42  2023-09-14 17:01:18
#
#       start_station_name start_station_id       end_station_name  \
# 0  Baldwin at Montgomery            JC020     Liberty Light Rail
# 1  Baldwin at Montgomery            JC020            Exchange Pl
# 2  Baldwin at Montgomery            JC020  Baldwin at Montgomery
# 3  Baldwin at Montgomery            JC020  Baldwin at Montgomery
# 4  Baldwin at Montgomery            JC020            Paulus Hook
#
#   end_station_id  start_lat  start_lng    end_lat    end_lng member_casual
# ...

# %%
# Drop all null NaN or empty values

df = df.dropna(how='any')

df
# Out:
#                 ride_id  rideable_type           started_at  \
# 0      4052081EAF41D252   classic_bike  2023-09-01 17:25:27
# 1      330043C418DD78E3   classic_bike  2023-09-01 12:57:39
# 2      4D0F3462818482CF   classic_bike  2023-09-28 08:52:24
# 3      BF4A3EBF9352E283   classic_bike  2023-09-02 15:25:33
# 4      957FA73CA6E0C552   classic_bike  2023-09-14 16:46:42
# ...                 ...            ...                  ...
# 94228  A2112D905D1B5FB9  electric_bike  2023-09-05 18:31:42
# 94229  2C9D64FF1B8C44C8   classic_bike  2023-09-25 08:36:13
# 94230  4F4E24251BBAB45E   classic_bike  2023-09-19 07:55:23
# 94231  BB6F0D74150403AC   classic_bike  2023-09-14 07:50:23
# 94232  755AE0D4205C0306   classic_bike  2023-09-22 06:52:07
#
#                   ended_at     start_station_name start_station_id  \
# 0      2023-09-01 17:31:13  Baldwin at Montgomery            JC020
# 1      2023-09-01 13:08:50  Baldwin at Montgomery            JC020
# ...

# %%
#Export cleaned data into a CSV file

df.to_csv("Cleaned_data/JC-202309-citibike-tripdata_clean.csv")

# %%
df.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# dtype: object
